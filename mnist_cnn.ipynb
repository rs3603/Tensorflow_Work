# %%
import tensorflow as tf

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# %%
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

# %%
x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 10])
x_image = tf.reshape(x, [-1,28,28,1])

# %%
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# %%
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# %%
W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# %%
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# %%
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_conv, y_))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
sess = tf.Session()
init = tf.initialize_all_variables()
sess.run(init)
for i in range(100000):
    batch = mnist.train.next_batch(100)
    if i%100 == 0:
        train_accuracy = sess.run(accuracy, feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})
        print("step %d, training accuracy %g"%(i, train_accuracy))
        sess.run(train_step, feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

print("test accuracy %g"%sess.run(accuracy, feed_dict={x: mnist.test.images[:1000], y_: mnist.test.labels[:1000], keep_prob: 1}))
# Out:
# step 0, training accuracy 0.07
# step 100, training accuracy 0.08
# step 200, training accuracy 0.07
# step 300, training accuracy 0.08
# step 400, training accuracy 0.16
# step 500, training accuracy 0.24
# step 600, training accuracy 0.28
# step 700, training accuracy 0.28
# step 800, training accuracy 0.24
# step 900, training accuracy 0.32
# step 1000, training accuracy 0.25
# step 1100, training accuracy 0.36
# step 1200, training accuracy 0.36
# step 1300, training accuracy 0.34
# step 1400, training accuracy 0.38
# step 1500, training accuracy 0.49
# step 1600, training accuracy 0.39
# step 1700, training accuracy 0.43
# step 1800, training accuracy 0.49
# step 1900, training accuracy 0.51
# step 2000, training accuracy 0.47
# step 2100, training accuracy 0.45
# step 2200, training accuracy 0.48
# step 2300, training accuracy 0.65
# step 2400, training accuracy 0.58
# step 2500, training accuracy 0.57
# step 2600, training accuracy 0.54
# step 2700, training accuracy 0.66
# step 2800, training accuracy 0.63
# step 2900, training accuracy 0.58
# step 3000, training accuracy 0.51
# step 3100, training accuracy 0.61
# step 3200, training accuracy 0.72
# step 3300, training accuracy 0.62
# step 3400, training accuracy 0.62
# step 3500, training accuracy 0.66
# step 3600, training accuracy 0.74
# step 3700, training accuracy 0.69
# step 3800, training accuracy 0.69
# step 3900, training accuracy 0.75
# step 4000, training accuracy 0.76
# step 4100, training accuracy 0.73
# step 4200, training accuracy 0.74
# step 4300, training accuracy 0.71
# step 4400, training accuracy 0.69
# step 4500, training accuracy 0.72
# step 4600, training accuracy 0.63
# step 4700, training accuracy 0.73
# step 4800, training accuracy 0.79
# step 4900, training accuracy 0.71
# step 5000, training accuracy 0.76
# step 5100, training accuracy 0.74
# step 5200, training accuracy 0.73
# step 5300, training accuracy 0.69
# step 5400, training accuracy 0.78
# step 5500, training accuracy 0.81
# step 5600, training accuracy 0.75
# step 5700, training accuracy 0.67
# step 5800, training accuracy 0.73
# step 5900, training accuracy 0.85
# step 6000, training accuracy 0.81
# step 6100, training accuracy 0.84
# step 6200, training accuracy 0.78
# step 6300, training accuracy 0.78
# step 6400, training accuracy 0.8
# step 6500, training accuracy 0.75
# step 6600, training accuracy 0.8
# step 6700, training accuracy 0.79
# step 6800, training accuracy 0.79
# step 6900, training accuracy 0.82
# step 7000, training accuracy 0.89
# step 7100, training accuracy 0.94
# step 7200, training accuracy 0.81
# step 7300, training accuracy 0.82
# step 7400, training accuracy 0.79
# step 7500, training accuracy 0.8
# step 7600, training accuracy 0.8
# step 7700, training accuracy 0.85
# step 7800, training accuracy 0.85
# step 7900, training accuracy 0.82
# step 8000, training accuracy 0.89
# step 8100, training accuracy 0.76
# step 8200, training accuracy 0.86
# step 8300, training accuracy 0.8
# step 8400, training accuracy 0.86
# step 8500, training accuracy 0.83
# step 8600, training accuracy 0.85
# step 8700, training accuracy 0.85
# step 8800, training accuracy 0.8
# step 8900, training accuracy 0.86
# step 9000, training accuracy 0.85
# step 9100, training accuracy 0.88
# step 9200, training accuracy 0.82
# step 9300, training accuracy 0.9
# step 9400, training accuracy 0.85
# step 9500, training accuracy 0.82
# step 9600, training accuracy 0.86
# step 9700, training accuracy 0.87
# step 9800, training accuracy 0.94
# step 9900, training accuracy 0.89
# step 10000, training accuracy 0.86
# step 10100, training accuracy 0.76
# step 10200, training accuracy 0.89
# step 10300, training accuracy 0.83
# step 10400, training accuracy 0.9
# step 10500, training accuracy 0.87
# step 10600, training accuracy 0.87
# step 10700, training accuracy 0.82
# step 10800, training accuracy 0.86
# step 10900, training accuracy 0.83
# step 11000, training accuracy 0.94
# step 11100, training accuracy 0.9
# step 11200, training accuracy 0.88
# step 11300, training accuracy 0.9
# step 11400, training accuracy 0.9
# step 11500, training accuracy 0.88
# step 11600, training accuracy 0.93
# step 11700, training accuracy 0.87
# step 11800, training accuracy 0.81
# step 11900, training accuracy 0.88
# step 12000, training accuracy 0.9
# step 12100, training accuracy 0.86
# step 12200, training accuracy 0.82
# step 12300, training accuracy 0.92
# step 12400, training accuracy 0.94
# step 12500, training accuracy 0.85
# step 12600, training accuracy 0.89
# step 12700, training accuracy 0.87
# step 12800, training accuracy 0.86
# step 12900, training accuracy 0.88
# step 13000, training accuracy 0.89
# step 13100, training accuracy 0.88
# step 13200, training accuracy 0.92
# step 13300, training accuracy 0.88
# step 13400, training accuracy 0.93
# step 13500, training accuracy 0.92
# step 13600, training accuracy 0.92
# step 13700, training accuracy 0.88
# step 13800, training accuracy 0.83
# step 13900, training accuracy 0.86
# step 14000, training accuracy 0.82
# step 14100, training accuracy 0.88
# step 14200, training accuracy 0.91
# step 14300, training accuracy 0.94
# step 14400, training accuracy 0.93
# step 14500, training accuracy 0.92
# step 14600, training accuracy 0.86
# step 14700, training accuracy 0.91
# step 14800, training accuracy 0.84
# step 14900, training accuracy 0.89
# step 15000, training accuracy 0.91
# step 15100, training accuracy 0.86
# step 15200, training accuracy 0.92
# step 15300, training accuracy 0.89
# step 15400, training accuracy 0.96
# step 15500, training accuracy 0.87
# step 15600, training accuracy 0.91
# step 15700, training accuracy 0.94
# step 15800, training accuracy 0.92
# step 15900, training accuracy 0.91
# step 16000, training accuracy 0.94
# step 16100, training accuracy 0.94
# step 16200, training accuracy 0.96
# step 16300, training accuracy 0.93
# step 16400, training accuracy 0.9
# step 16500, training accuracy 0.9
# step 16600, training accuracy 0.92
# step 16700, training accuracy 0.9
# step 16800, training accuracy 0.95
# step 16900, training accuracy 0.92
# step 17000, training accuracy 0.89
# step 17100, training accuracy 0.87
# step 17200, training accuracy 0.94
# step 17300, training accuracy 0.89
# step 17400, training accuracy 0.91
# step 17500, training accuracy 0.89
# step 17600, training accuracy 0.95
# step 17700, training accuracy 0.89
# step 17800, training accuracy 0.94
# step 17900, training accuracy 0.88
# step 18000, training accuracy 0.97
# step 18100, training accuracy 0.94
# step 18200, training accuracy 0.9
# step 18300, training accuracy 0.92
# step 18400, training accuracy 0.91
# step 18500, training accuracy 0.94
# step 18600, training accuracy 0.9
# step 18700, training accuracy 0.95
# step 18800, training accuracy 0.96
# step 18900, training accuracy 0.91
# step 19000, training accuracy 0.96
# step 19100, training accuracy 0.9
# step 19200, training accuracy 0.92
# step 19300, training accuracy 0.9
# step 19400, training accuracy 0.95
# step 19500, training accuracy 0.92
# step 19600, training accuracy 0.95
# step 19700, training accuracy 0.91
# step 19800, training accuracy 0.94
# step 19900, training accuracy 0.88
# step 20000, training accuracy 0.94
# step 20100, training accuracy 0.94
# step 20200, training accuracy 0.95
# step 20300, training accuracy 0.95
# step 20400, training accuracy 0.95
# step 20500, training accuracy 0.9
# step 20600, training accuracy 0.92
# step 20700, training accuracy 0.86
# step 20800, training accuracy 0.91
# step 20900, training accuracy 0.92
# step 21000, training accuracy 0.9
# step 21100, training accuracy 0.91
# step 21200, training accuracy 0.94
# step 21300, training accuracy 0.92
# step 21400, training accuracy 0.91
# step 21500, training accuracy 0.91
# step 21600, training accuracy 0.93
# step 21700, training accuracy 0.94
# step 21800, training accuracy 0.94
# step 21900, training accuracy 0.9
# step 22000, training accuracy 0.92
# step 22100, training accuracy 0.93
# step 22200, training accuracy 0.91
# step 22300, training accuracy 0.94
# step 22400, training accuracy 0.95
# step 22500, training accuracy 0.89
# step 22600, training accuracy 0.97
# step 22700, training accuracy 0.95
# step 22800, training accuracy 0.96
# step 22900, training accuracy 0.93
# step 23000, training accuracy 0.97
# step 23100, training accuracy 0.91
# step 23200, training accuracy 0.94
# step 23300, training accuracy 0.97
# step 23400, training accuracy 0.88
# step 23500, training accuracy 0.93
# step 23600, training accuracy 0.93
# step 23700, training accuracy 0.92
# step 23800, training accuracy 0.95
# step 23900, training accuracy 0.93
# step 24000, training accuracy 0.93
# step 24100, training accuracy 0.94
# step 24200, training accuracy 0.93
# step 24300, training accuracy 0.91
# step 24400, training accuracy 0.95
# step 24500, training accuracy 0.95
# step 24600, training accuracy 0.93
# step 24700, training accuracy 0.93
# step 24800, training accuracy 0.88
# step 24900, training accuracy 0.93
# step 25000, training accuracy 0.91
# step 25100, training accuracy 0.92
# step 25200, training accuracy 0.93
# step 25300, training accuracy 0.97
# step 25400, training accuracy 0.96
# step 25500, training accuracy 0.96
# step 25600, training accuracy 0.95
# step 25700, training accuracy 0.95
# step 25800, training accuracy 0.96
# step 25900, training accuracy 0.97
# step 26000, training accuracy 0.93
# step 26100, training accuracy 0.97
# step 26200, training accuracy 0.94
# step 26300, training accuracy 0.97
# step 26400, training accuracy 0.91
# step 26500, training accuracy 0.92
# step 26600, training accuracy 0.98
# step 26700, training accuracy 0.95
# step 26800, training accuracy 0.93
# step 26900, training accuracy 0.95
# step 27000, training accuracy 0.94
# step 27100, training accuracy 0.96
# step 27200, training accuracy 0.93
# step 27300, training accuracy 0.93
# step 27400, training accuracy 0.95
# step 27500, training accuracy 0.98
# step 27600, training accuracy 1
# step 27700, training accuracy 0.94
# step 27800, training accuracy 0.93
# step 27900, training accuracy 0.97
# step 28000, training accuracy 0.95
# step 28100, training accuracy 0.96
# step 28200, training accuracy 0.94
# step 28300, training accuracy 0.94
# step 28400, training accuracy 0.97
# step 28500, training accuracy 0.94
# step 28600, training accuracy 0.96
# step 28700, training accuracy 0.95
# step 28800, training accuracy 0.94
# step 28900, training accuracy 0.97
# step 29000, training accuracy 0.96
# step 29100, training accuracy 0.85
# step 29200, training accuracy 0.94
# step 29300, training accuracy 0.95
# step 29400, training accuracy 0.9
# step 29500, training accuracy 0.96
# step 29600, training accuracy 0.96
# step 29700, training accuracy 0.94
# step 29800, training accuracy 0.94
# step 29900, training accuracy 0.94
# step 30000, training accuracy 0.96
# step 30100, training accuracy 0.96
# step 30200, training accuracy 0.94
# step 30300, training accuracy 0.95
# step 30400, training accuracy 0.95
# step 30500, training accuracy 0.96
# step 30600, training accuracy 0.96
# step 30700, training accuracy 0.95
# step 30800, training accuracy 0.94
# step 30900, training accuracy 0.96
# step 31000, training accuracy 0.92
# step 31100, training accuracy 0.96
# step 31200, training accuracy 0.9
# step 31300, training accuracy 0.96
# step 31400, training accuracy 0.93
# step 31500, training accuracy 0.97
# step 31600, training accuracy 0.93
# step 31700, training accuracy 0.94
# step 31800, training accuracy 0.95
# step 31900, training accuracy 0.91
# step 32000, training accuracy 0.95
# step 32100, training accuracy 0.98
# step 32200, training accuracy 0.9
# step 32300, training accuracy 0.92
# step 32400, training accuracy 0.95
# step 32500, training accuracy 0.93
# step 32600, training accuracy 0.93
# step 32700, training accuracy 0.95
# step 32800, training accuracy 0.96
# step 32900, training accuracy 0.89
# step 33000, training accuracy 0.98
# step 33100, training accuracy 0.96
# step 33200, training accuracy 0.97
# step 33300, training accuracy 0.95
# step 33400, training accuracy 0.94
# step 33500, training accuracy 0.95
# step 33600, training accuracy 0.98
# step 33700, training accuracy 0.96
# step 33800, training accuracy 0.96
# step 33900, training accuracy 0.95
# step 34000, training accuracy 0.94
# step 34100, training accuracy 0.91
# step 34200, training accuracy 0.94
# step 34300, training accuracy 0.9
# step 34400, training accuracy 0.95
# step 34500, training accuracy 0.93
# step 34600, training accuracy 0.93
# step 34700, training accuracy 0.9
# step 34800, training accuracy 0.9
# step 34900, training accuracy 0.98
# step 35000, training accuracy 0.93
# step 35100, training accuracy 0.96
# step 35200, training accuracy 0.93
# step 35300, training accuracy 0.94
# step 35400, training accuracy 0.95
# step 35500, training accuracy 0.94
# step 35600, training accuracy 0.92
# step 35700, training accuracy 0.92
# step 35800, training accuracy 0.92
# step 35900, training accuracy 0.97
# step 36000, training accuracy 0.93
# step 36100, training accuracy 0.93
# step 36200, training accuracy 0.95
# step 36300, training accuracy 0.91
# step 36400, training accuracy 0.95
# step 36500, training accuracy 0.88
# step 36600, training accuracy 0.95
# step 36700, training accuracy 0.93
# step 36800, training accuracy 0.95
# step 36900, training accuracy 0.93
# step 37000, training accuracy 0.94
# step 37100, training accuracy 0.95
# step 37200, training accuracy 0.95
# step 37300, training accuracy 0.94
# step 37400, training accuracy 0.97
# step 37500, training accuracy 0.95
# step 37600, training accuracy 0.98
# step 37700, training accuracy 1
# step 37800, training accuracy 0.98
# step 37900, training accuracy 0.95
# step 38000, training accuracy 0.95
# step 38100, training accuracy 0.96
# step 38200, training accuracy 0.96
# step 38300, training accuracy 0.96
# step 38400, training accuracy 0.91
# step 38500, training accuracy 0.92
# step 38600, training accuracy 0.97
# step 38700, training accuracy 0.92
# step 38800, training accuracy 0.96
# step 38900, training accuracy 0.96
# step 39000, training accuracy 0.97
# step 39100, training accuracy 0.95
# step 39200, training accuracy 0.98
# step 39300, training accuracy 0.97
# step 39400, training accuracy 0.94
# step 39500, training accuracy 0.97
# step 39600, training accuracy 0.97
# step 39700, training accuracy 0.96
# step 39800, training accuracy 0.98
# step 39900, training accuracy 0.97
# step 40000, training accuracy 0.97
# step 40100, training accuracy 0.94
# step 40200, training accuracy 0.99
# step 40300, training accuracy 0.93
# step 40400, training accuracy 0.96
# step 40500, training accuracy 0.94
# step 40600, training accuracy 0.92
# step 40700, training accuracy 0.97
# step 40800, training accuracy 0.96
# step 40900, training accuracy 0.92
# step 41000, training accuracy 0.97
# step 41100, training accuracy 0.95
# step 41200, training accuracy 0.95
# step 41300, training accuracy 0.95
# step 41400, training accuracy 0.94
# step 41500, training accuracy 0.92
# step 41600, training accuracy 0.97
# step 41700, training accuracy 0.96
# step 41800, training accuracy 0.95
# step 41900, training accuracy 0.94
# step 42000, training accuracy 0.98
# step 42100, training accuracy 0.93
# step 42200, training accuracy 0.98
# step 42300, training accuracy 0.96
# step 42400, training accuracy 0.95
# step 42500, training accuracy 0.97
# step 42600, training accuracy 0.95
# step 42700, training accuracy 0.95
# step 42800, training accuracy 0.93
# step 42900, training accuracy 0.94
# step 43000, training accuracy 0.97
# step 43100, training accuracy 0.93
# step 43200, training accuracy 0.92
# step 43300, training accuracy 0.94
# step 43400, training accuracy 0.92
# step 43500, training accuracy 0.95
# step 43600, training accuracy 0.98
# step 43700, training accuracy 0.99
# step 43800, training accuracy 0.96
# step 43900, training accuracy 0.95
# step 44000, training accuracy 0.92
# step 44100, training accuracy 0.96
# step 44200, training accuracy 0.97
# step 44300, training accuracy 0.97
# step 44400, training accuracy 0.94
# step 44500, training accuracy 0.93
# step 44600, training accuracy 0.97
# step 44700, training accuracy 0.91
# step 44800, training accuracy 0.91
# step 44900, training accuracy 0.93
# step 45000, training accuracy 0.96
# step 45100, training accuracy 0.97
# step 45200, training accuracy 0.95
# step 45300, training accuracy 0.94
# step 45400, training accuracy 0.97
# step 45500, training accuracy 0.91
# step 45600, training accuracy 0.94
# step 45700, training accuracy 0.94
# step 45800, training accuracy 0.89
# step 45900, training accuracy 0.95
# step 46000, training accuracy 0.97
# step 46100, training accuracy 0.95
# step 46200, training accuracy 0.97
# step 46300, training accuracy 0.99
# step 46400, training accuracy 0.94
# step 46500, training accuracy 0.97
# step 46600, training accuracy 0.97
# step 46700, training accuracy 0.96
# step 46800, training accuracy 0.93
# step 46900, training accuracy 0.95
# step 47000, training accuracy 0.99
# step 47100, training accuracy 0.93
# step 47200, training accuracy 0.96
# step 47300, training accuracy 0.93
# step 47400, training accuracy 0.94
# step 47500, training accuracy 0.97
# step 47600, training accuracy 0.95
# step 47700, training accuracy 0.99
# step 47800, training accuracy 0.93
# step 47900, training accuracy 0.95
# step 48000, training accuracy 0.95
# step 48100, training accuracy 0.97
# step 48200, training accuracy 0.95
# step 48300, training accuracy 0.94
# step 48400, training accuracy 0.94
# step 48500, training accuracy 0.93
# step 48600, training accuracy 0.96
# step 48700, training accuracy 0.98
# step 48800, training accuracy 0.93
# step 48900, training accuracy 0.95
# step 49000, training accuracy 0.93
# step 49100, training accuracy 0.98
# step 49200, training accuracy 0.97
# step 49300, training accuracy 0.95
# step 49400, training accuracy 0.92
# step 49500, training accuracy 0.95
# step 49600, training accuracy 0.91
# step 49700, training accuracy 0.97
# step 49800, training accuracy 0.96
# step 49900, training accuracy 0.96
# step 50000, training accuracy 0.97
# step 50100, training accuracy 0.95
# step 50200, training accuracy 0.94
# step 50300, training accuracy 0.94
# step 50400, training accuracy 0.92
# step 50500, training accuracy 0.93
# step 50600, training accuracy 0.93
# step 50700, training accuracy 0.95
# step 50800, training accuracy 0.92
# step 50900, training accuracy 0.92
# step 51000, training accuracy 0.94
# step 51100, training accuracy 0.94
# step 51200, training accuracy 0.95
# step 51300, training accuracy 0.97
# step 51400, training accuracy 0.91
# step 51500, training accuracy 0.96
# step 51600, training accuracy 0.99
# step 51700, training accuracy 0.94
# step 51800, training accuracy 0.93
# step 51900, training accuracy 0.96
# step 52000, training accuracy 0.94
# step 52100, training accuracy 0.93
# step 52200, training accuracy 0.95
# step 52300, training accuracy 0.98
# step 52400, training accuracy 0.97
# step 52500, training accuracy 0.96
# step 52600, training accuracy 0.95
# step 52700, training accuracy 0.99
# step 52800, training accuracy 0.96
# step 52900, training accuracy 0.96
# step 53000, training accuracy 0.94
# step 53100, training accuracy 0.95
# step 53200, training accuracy 0.97
# step 53300, training accuracy 0.96
# step 53400, training accuracy 0.95
# step 53500, training accuracy 0.99
# step 53600, training accuracy 0.97
# step 53700, training accuracy 0.98
# step 53800, training accuracy 0.98
# step 53900, training accuracy 0.93
# step 54000, training accuracy 0.94
# step 54100, training accuracy 0.99
# step 54200, training accuracy 0.97
# step 54300, training accuracy 0.94
# step 54400, training accuracy 0.98
# step 54500, training accuracy 0.98
# step 54600, training accuracy 0.95
# step 54700, training accuracy 0.94
# step 54800, training accuracy 0.95
# step 54900, training accuracy 0.95
# step 55000, training accuracy 0.96
# step 55100, training accuracy 0.95
# step 55200, training accuracy 0.98
# step 55300, training accuracy 0.94
# step 55400, training accuracy 0.93
# step 55500, training accuracy 0.94
# step 55600, training accuracy 0.99
# step 55700, training accuracy 0.98
# step 55800, training accuracy 0.95
# step 55900, training accuracy 0.92
# step 56000, training accuracy 0.95
# step 56100, training accuracy 0.94
# step 56200, training accuracy 0.97
# step 56300, training accuracy 0.97
# step 56400, training accuracy 0.97
# step 56500, training accuracy 0.99
# step 56600, training accuracy 0.96
# step 56700, training accuracy 0.96
# step 56800, training accuracy 0.95
# step 56900, training accuracy 0.94
# step 57000, training accuracy 0.97
# step 57100, training accuracy 0.98
# step 57200, training accuracy 0.97
# step 57300, training accuracy 0.98
# step 57400, training accuracy 0.96
# step 57500, training accuracy 0.96
# step 57600, training accuracy 0.95
# step 57700, training accuracy 0.98
# step 57800, training accuracy 0.97
# step 57900, training accuracy 0.94
# step 58000, training accuracy 0.98
# step 58100, training accuracy 0.96
# step 58200, training accuracy 0.97
# step 58300, training accuracy 0.96
# step 58400, training accuracy 0.98
# step 58500, training accuracy 0.95
# step 58600, training accuracy 0.93
# step 58700, training accuracy 0.97
# step 58800, training accuracy 0.95
# step 58900, training accuracy 0.97
# step 59000, training accuracy 0.94
# step 59100, training accuracy 0.95
# step 59200, training accuracy 0.96
# step 59300, training accuracy 0.93
# step 59400, training accuracy 0.96
# step 59500, training accuracy 0.95
# step 59600, training accuracy 0.97
# step 59700, training accuracy 0.97
# step 59800, training accuracy 0.97
# step 59900, training accuracy 0.95
# step 60000, training accuracy 0.98
# step 60100, training accuracy 0.97
# step 60200, training accuracy 0.97
# step 60300, training accuracy 0.96
# step 60400, training accuracy 0.98
# step 60500, training accuracy 0.97
# step 60600, training accuracy 0.98
# step 60700, training accuracy 0.97
# step 60800, training accuracy 1
# step 60900, training accuracy 0.99
# step 61000, training accuracy 0.95
# step 61100, training accuracy 0.92
# step 61200, training accuracy 0.96
# step 61300, training accuracy 0.98
# step 61400, training accuracy 0.98
# step 61500, training accuracy 0.98
# step 61600, training accuracy 0.98
# step 61700, training accuracy 0.95
# step 61800, training accuracy 0.96
# step 61900, training accuracy 0.95
# step 62000, training accuracy 0.99
# step 62100, training accuracy 0.94
# step 62200, training accuracy 0.99
# step 62300, training accuracy 0.98
# step 62400, training accuracy 0.97
# step 62500, training accuracy 0.98
# step 62600, training accuracy 0.98
# step 62700, training accuracy 0.98
# step 62800, training accuracy 0.93
# step 62900, training accuracy 0.95
# step 63000, training accuracy 0.98
# step 63100, training accuracy 0.96
# step 63200, training accuracy 0.97
# step 63300, training accuracy 0.98
# step 63400, training accuracy 0.96
# step 63500, training accuracy 0.98
# step 63600, training accuracy 0.96
# step 63700, training accuracy 0.92
# step 63800, training accuracy 0.93
# step 63900, training accuracy 0.98
# step 64000, training accuracy 0.95
# step 64100, training accuracy 0.95
# step 64200, training accuracy 0.99
# step 64300, training accuracy 0.97
# step 64400, training accuracy 0.96
# step 64500, training accuracy 0.95
# step 64600, training accuracy 0.94
# step 64700, training accuracy 0.97
# step 64800, training accuracy 0.95
# step 64900, training accuracy 0.95
# step 65000, training accuracy 0.97
# step 65100, training accuracy 0.95
# step 65200, training accuracy 0.95
# step 65300, training accuracy 0.99
# step 65400, training accuracy 0.98
# step 65500, training accuracy 0.96
# step 65600, training accuracy 0.93
# step 65700, training accuracy 0.91
# step 65800, training accuracy 0.92
# step 65900, training accuracy 0.93
# step 66000, training accuracy 0.93
# step 66100, training accuracy 0.97
# step 66200, training accuracy 0.98
# step 66300, training accuracy 0.94
# step 66400, training accuracy 0.93
# step 66500, training accuracy 0.98
# step 66600, training accuracy 0.96
# step 66700, training accuracy 0.99
# step 66800, training accuracy 0.92
# step 66900, training accuracy 0.96
# step 67000, training accuracy 0.96
# step 67100, training accuracy 0.95
# step 67200, training accuracy 0.99
# step 67300, training accuracy 0.95
# step 67400, training accuracy 0.92
# step 67500, training accuracy 0.94
# step 67600, training accuracy 0.93
# step 67700, training accuracy 0.95
# step 67800, training accuracy 0.97
# step 67900, training accuracy 0.96
# step 68000, training accuracy 0.96
# step 68100, training accuracy 0.97
# step 68200, training accuracy 0.97
# step 68300, training accuracy 0.96
# step 68400, training accuracy 0.97
# step 68500, training accuracy 0.93
# step 68600, training accuracy 0.94
# step 68700, training accuracy 0.95
# step 68800, training accuracy 0.99
# step 68900, training accuracy 0.99
# step 69000, training accuracy 0.99
# step 69100, training accuracy 0.98
# step 69200, training accuracy 0.98
# step 69300, training accuracy 0.96
# step 69400, training accuracy 0.94
# step 69500, training accuracy 0.99
# step 69600, training accuracy 0.99
# step 69700, training accuracy 0.96
# step 69800, training accuracy 0.98
# step 69900, training accuracy 0.95
# step 70000, training accuracy 0.96
# step 70100, training accuracy 0.95
# step 70200, training accuracy 0.96
# step 70300, training accuracy 1
# step 70400, training accuracy 0.98
# step 70500, training accuracy 0.96
# step 70600, training accuracy 0.97
# step 70700, training accuracy 0.95
# step 70800, training accuracy 0.99
# step 70900, training accuracy 0.97
# step 71000, training accuracy 0.96
# step 71100, training accuracy 0.97
# step 71200, training accuracy 0.98
# step 71300, training accuracy 0.96
# step 71400, training accuracy 0.96
# step 71500, training accuracy 0.95
# step 71600, training accuracy 0.98
# step 71700, training accuracy 0.98
# step 71800, training accuracy 0.98
# step 71900, training accuracy 0.95
# step 72000, training accuracy 0.95
# step 72100, training accuracy 0.95
# step 72200, training accuracy 0.98
# step 72300, training accuracy 0.99
# step 72400, training accuracy 0.95
# step 72500, training accuracy 0.97
# step 72600, training accuracy 0.94
# step 72700, training accuracy 0.96
# step 72800, training accuracy 1
# step 72900, training accuracy 0.98
# step 73000, training accuracy 0.92
# step 73100, training accuracy 0.98
# step 73200, training accuracy 0.95
# step 73300, training accuracy 0.96
# step 73400, training accuracy 0.94
# step 73500, training accuracy 0.96
# step 73600, training accuracy 0.97
# step 73700, training accuracy 0.92
# step 73800, training accuracy 0.93
# step 73900, training accuracy 0.98
# step 74000, training accuracy 0.96
# step 74100, training accuracy 0.96
# step 74200, training accuracy 0.96
# step 74300, training accuracy 0.99
# step 74400, training accuracy 0.93
# step 74500, training accuracy 0.94
# step 74600, training accuracy 0.96
# step 74700, training accuracy 0.94
# step 74800, training accuracy 0.99
# step 74900, training accuracy 0.97
# step 75000, training accuracy 0.96
# step 75100, training accuracy 0.99
# step 75200, training accuracy 0.98
# step 75300, training accuracy 0.97
# step 75400, training accuracy 0.94
# step 75500, training accuracy 0.92
# step 75600, training accuracy 0.96
# step 75700, training accuracy 0.93
# step 75800, training accuracy 0.95
# step 75900, training accuracy 0.97
# step 76000, training accuracy 0.96
# step 76100, training accuracy 0.97
# step 76200, training accuracy 0.99
# step 76300, training accuracy 0.98
# step 76400, training accuracy 0.95
# step 76500, training accuracy 0.98
# step 76600, training accuracy 0.97
# step 76700, training accuracy 0.96
# step 76800, training accuracy 0.96
# step 76900, training accuracy 0.96
# step 77000, training accuracy 0.95
# step 77100, training accuracy 0.97
# step 77200, training accuracy 0.98
# step 77300, training accuracy 0.97
# step 77400, training accuracy 0.93
# step 77500, training accuracy 0.97
# step 77600, training accuracy 0.96
# step 77700, training accuracy 0.98
# step 77800, training accuracy 0.98
# step 77900, training accuracy 0.92
# step 78000, training accuracy 0.99
# step 78100, training accuracy 0.98
# step 78200, training accuracy 0.99
# step 78300, training accuracy 0.96
# step 78400, training accuracy 0.99
# step 78500, training accuracy 0.96
# step 78600, training accuracy 0.97
# step 78700, training accuracy 0.97
# step 78800, training accuracy 0.97
# step 78900, training accuracy 0.96
# step 79000, training accuracy 0.95
# step 79100, training accuracy 0.94
# step 79200, training accuracy 0.98
# step 79300, training accuracy 0.99
# step 79400, training accuracy 0.97
# step 79500, training accuracy 0.92
# step 79600, training accuracy 0.98
# step 79700, training accuracy 0.96
# step 79800, training accuracy 0.99
# step 79900, training accuracy 0.97
# step 80000, training accuracy 0.96
# step 80100, training accuracy 0.96
# step 80200, training accuracy 0.93
# step 80300, training accuracy 0.96
# step 80400, training accuracy 0.95
# step 80500, training accuracy 0.98
# step 80600, training accuracy 0.96
# step 80700, training accuracy 0.97
# step 80800, training accuracy 0.95
# step 80900, training accuracy 0.96
# step 81000, training accuracy 0.94
# step 81100, training accuracy 0.96
# step 81200, training accuracy 0.96
# step 81300, training accuracy 0.97
# step 81400, training accuracy 0.96
# step 81500, training accuracy 0.96
# step 81600, training accuracy 0.94
# step 81700, training accuracy 0.97
# step 81800, training accuracy 0.98
# step 81900, training accuracy 0.99
# step 82000, training accuracy 0.96
# step 82100, training accuracy 0.96
# step 82200, training accuracy 0.99
# step 82300, training accuracy 0.98
# step 82400, training accuracy 0.98
# step 82500, training accuracy 0.99
# step 82600, training accuracy 1
# step 82700, training accuracy 0.99
# step 82800, training accuracy 0.98
# step 82900, training accuracy 0.95
# step 83000, training accuracy 0.96
# step 83100, training accuracy 0.96
# step 83200, training accuracy 0.98
# step 83300, training accuracy 1
# step 83400, training accuracy 0.95
# step 83500, training accuracy 0.99
# step 83600, training accuracy 0.96
# step 83700, training accuracy 0.99
# step 83800, training accuracy 0.97
# step 83900, training accuracy 0.98
# step 84000, training accuracy 0.99
# step 84100, training accuracy 0.93
# step 84200, training accuracy 0.93
# step 84300, training accuracy 0.99
# step 84400, training accuracy 0.98
# step 84500, training accuracy 0.96
# step 84600, training accuracy 0.95
# step 84700, training accuracy 0.97
# step 84800, training accuracy 1
# step 84900, training accuracy 0.95
# step 85000, training accuracy 0.96
# step 85100, training accuracy 0.97
# step 85200, training accuracy 0.96
# step 85300, training accuracy 0.98
# step 85400, training accuracy 0.99
# step 85500, training accuracy 0.96
# step 85600, training accuracy 0.96
# step 85700, training accuracy 0.98
# step 85800, training accuracy 0.96
# step 85900, training accuracy 0.95
# step 86000, training accuracy 0.98
# step 86100, training accuracy 0.99
# step 86200, training accuracy 0.91
# step 86300, training accuracy 0.99
# step 86400, training accuracy 0.91
# step 86500, training accuracy 0.97
# step 86600, training accuracy 0.99
# step 86700, training accuracy 0.98
# step 86800, training accuracy 0.99
# step 86900, training accuracy 0.97
# step 87000, training accuracy 0.95
# step 87100, training accuracy 0.98
# step 87200, training accuracy 0.95
# step 87300, training accuracy 0.97
# step 87400, training accuracy 0.94
# step 87500, training accuracy 0.96
# step 87600, training accuracy 0.98
# step 87700, training accuracy 0.98
# step 87800, training accuracy 0.96
# step 87900, training accuracy 0.96
# step 88000, training accuracy 0.95
# step 88100, training accuracy 0.99
# step 88200, training accuracy 0.98
# step 88300, training accuracy 0.99
# step 88400, training accuracy 0.98
# step 88500, training accuracy 0.99
# step 88600, training accuracy 0.98
# step 88700, training accuracy 0.97
# step 88800, training accuracy 0.98
# step 88900, training accuracy 0.99
# step 89000, training accuracy 0.98
# step 89100, training accuracy 0.97
# step 89200, training accuracy 0.98
# step 89300, training accuracy 0.99
# step 89400, training accuracy 0.96
# step 89500, training accuracy 0.98
# step 89600, training accuracy 0.94
# step 89700, training accuracy 0.95
# step 89800, training accuracy 0.97
# step 89900, training accuracy 0.99
# step 90000, training accuracy 0.97
# step 90100, training accuracy 0.96
# step 90200, training accuracy 0.95
# step 90300, training accuracy 0.97
# step 90400, training accuracy 0.99
# step 90500, training accuracy 0.97
# step 90600, training accuracy 0.99
# step 90700, training accuracy 0.98
# step 90800, training accuracy 0.99
# step 90900, training accuracy 0.99
# step 91000, training accuracy 0.98
# step 91100, training accuracy 0.99
# step 91200, training accuracy 0.93
# step 91300, training accuracy 0.92
# step 91400, training accuracy 0.96
# step 91500, training accuracy 0.96
# step 91600, training accuracy 0.98
# step 91700, training accuracy 0.99
# step 91800, training accuracy 0.97
# step 91900, training accuracy 0.97
# step 92000, training accuracy 0.99
# step 92100, training accuracy 0.98
# step 92200, training accuracy 0.95
# step 92300, training accuracy 0.98
# step 92400, training accuracy 0.97
# step 92500, training accuracy 0.98
# step 92600, training accuracy 0.96
# step 92700, training accuracy 0.99
# step 92800, training accuracy 0.97
# step 92900, training accuracy 0.95
# step 93000, training accuracy 0.99
# step 93100, training accuracy 0.98
# step 93200, training accuracy 0.96
# step 93300, training accuracy 0.98
# step 93400, training accuracy 0.94
# step 93500, training accuracy 0.98
# step 93600, training accuracy 0.95
# step 93700, training accuracy 0.98
# step 93800, training accuracy 0.97
# step 93900, training accuracy 0.98
# step 94000, training accuracy 0.94
# step 94100, training accuracy 0.98
# step 94200, training accuracy 0.95
# step 94300, training accuracy 0.98
# step 94400, training accuracy 0.97
# step 94500, training accuracy 0.97
# step 94600, training accuracy 0.98
# step 94700, training accuracy 0.97
# step 94800, training accuracy 0.98
# step 94900, training accuracy 0.95
# step 95000, training accuracy 0.96
# step 95100, training accuracy 0.96
# step 95200, training accuracy 0.97
# step 95300, training accuracy 0.94
# step 95400, training accuracy 0.97
# step 95500, training accuracy 0.99
# step 95600, training accuracy 0.93
# step 95700, training accuracy 0.97
# step 95800, training accuracy 0.97
# step 95900, training accuracy 0.98
# step 96000, training accuracy 0.98
# step 96100, training accuracy 0.97
# step 96200, training accuracy 0.94
# step 96300, training accuracy 0.99
# step 96400, training accuracy 0.97
# step 96500, training accuracy 0.99
# step 96600, training accuracy 0.94
# step 96700, training accuracy 0.97
# step 96800, training accuracy 0.93
# step 96900, training accuracy 0.98
# step 97000, training accuracy 1
# step 97100, training accuracy 1
# step 97200, training accuracy 0.99
# step 97300, training accuracy 0.96
# step 97400, training accuracy 1
# step 97500, training accuracy 0.96
# step 97600, training accuracy 0.94
# step 97700, training accuracy 0.94
# step 97800, training accuracy 0.94
# step 97900, training accuracy 0.94
# step 98000, training accuracy 0.96
# step 98100, training accuracy 0.99
# step 98200, training accuracy 0.98
# step 98300, training accuracy 0.98
# step 98400, training accuracy 0.97
# step 98500, training accuracy 0.98
# step 98600, training accuracy 0.95
# step 98700, training accuracy 0.95
# step 98800, training accuracy 0.97
# step 98900, training accuracy 0.97
# step 99000, training accuracy 0.92
# step 99100, training accuracy 0.98
# step 99200, training accuracy 0.95
# step 99300, training accuracy 0.98
# step 99400, training accuracy 0.96
# step 99500, training accuracy 0.97
# step 99600, training accuracy 0.97
# step 99700, training accuracy 0.98
# step 99800, training accuracy 0.93
# step 99900, training accuracy 0.97
# test accuracy 0.968
